# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiDheerajPeketi/Automated_Stock_Trading_Notifier/blob/main/Major_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Download the dataset

# %%
# !wget -r -N -c -np --user accdecoy --ask-password https://physionet.org/files/openox-repo/1.0.0/
# Out:
# Streaming output truncated to the last 5000 lines.
# 2025-01-29 14:56:44 (658 KB/s) - ‘physionet.org/files/openox-repo/1.0.0/waveforms/0/0722f4a1b9b9898552f37af0eadce621a3e407eb11c4b9d6cfb05e898f018ed6.dat’ saved [4669000/4669000]
#
# --2025-01-29 14:56:44--  https://physionet.org/files/openox-repo/1.0.0/waveforms/0/0722f4a1b9b9898552f37af0eadce621a3e407eb11c4b9d6cfb05e898f018ed6.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 706 [text/plain]
# Saving to: ‘physionet.org/files/openox-repo/1.0.0/waveforms/0/0722f4a1b9b9898552f37af0eadce621a3e407eb11c4b9d6cfb05e898f018ed6.hea’
#
# physionet.org/files 100%[===================>]     706  --.-KB/s    in 0s
#
# 2025-01-29 14:56:44 (298 MB/s) - ‘physionet.org/files/openox-repo/1.0.0/waveforms/0/0722f4a1b9b9898552f37af0eadce621a3e407eb11c4b9d6cfb05e898f018ed6.hea’ saved [706/706]
#
# ...
